# %%
#Stress Function Equation
import math
import numpy as np
import numpy.matlib
import matplotlib.pyplot as plt

# n Number of Compartments
n = 5

# Stress Function
a = (10/(1+1000*np.exp(-1*(0+x))))
b = (10/(1+1000*np.exp(-1*(-15+x))))
c = (10/(1+1000*np.exp(-1*(-15*2+x))))
d = (10/(1+1000*np.exp(-1*(-15*3+x))))
e = (10/(1+1000*np.exp(-1*(-15*4+x))))
f = (10/(1+1000*np.exp(-1*(-15*5+x))))

# X - axis Definition
x = np.linspace(0, 80, 100 )

if n == 1:
    y = a
elif n ==2:
    y = a + b 
elif n ==3:
    y = a + b + c
elif n ==4:
    y = a + b + c + d
elif n == 5:
    y = a + b + c + d + e

plt.plot(x,y)
plt.xlabel("Time")
plt.ylabel("Oxidative Stress")

plt.show()

# %%
num = 2
power = 3
product = 1
for _ in range(power):
    for n in range(power):
        product *= num
    
print (product)
# Out:
# 512

# %%
y = a = (10/(1+1000*np.exp(-1*(0+x))))
n = 3
        
# X - axis Definition
x = np.linspace(0, 80, 100 )

plt.plot(x,y
plt.xlabel("Time")
plt.ylabel("Oxidative Stress")

plt.show()
